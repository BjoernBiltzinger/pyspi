# %%
from spi_pointing import *
src_ra, src_dec = 197.075, 58.9803

# %%
pointing = SPIPointing('data/sc_orbit_param.fits.gz')

# %%
pointing.sc_points[4]['scx_ra']
# Out:
# 206.325684140497

# %%
pointing._sc_matrix.shape
# Out:
# (417, 3, 3)

# %%
bla = pointing._calc_zenazi(src_ra,src_dec)
# Out:
# [9.887821140650406, 356.8126097228868]
# [9.887821140650406, 356.8126097228868]
# [9.887821140650406, 356.8126097228868]
# [9.887821140650406, 356.8126097228868]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# [9.887523917891963, 356.81515608799265]
# ...

# %%
print(bla)
# Out:
# None

# %%
pointing._n_pointings
# Out:
# 417

# %%
            i = 0
            scx_ra  = pointing.sc_points[i]['scx_ra']
            scx_dec = pointing.sc_points[i]['scx_dec']
            scy_ra  = pointing.sc_points[i]['scy_ra']
            scy_dec = pointing.sc_points[i]['scy_dec']
            scz_ra  = pointing.sc_points[i]['scz_ra']
            scz_dec = pointing.sc_points[i]['scz_dec']

# %%
pointing._calc_zenazi()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-46d11565c122> in <module>()
# ----> 1 pointing._calc_zenazi()
#
# TypeError: _calc_zenazi() takes exactly 3 arguments (1 given)

# %%
import sys
sys.executable
