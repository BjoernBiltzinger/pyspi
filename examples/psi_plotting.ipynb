# %%
# Scientific libraries
import numpy as np

import pandas as pd


# Graphic libraries

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt


from pyspi import SPIResponse
from pyspi.spi_display import SPI, spi_pseudo_double_detectors

# %%
spi =SPI()

# %%
spi.plot_spi()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
spi_pseudo_double_detectors
# Out:
#     detector1  detector2  detector_number     x       y
# 0           0          1               19   3.0   0.000
# 1           0          2               20   1.5   2.598
# 2           0          3               21  -1.5   2.598
# 3           0          4               22  -3.0   0.000
# 4           0          5               23  -1.5  -2.598
# 5           0          6               24   1.5  -2.598
# 6           1          2               25   4.5   2.598
# 7           1          6               26   4.5  -2.598
# 8           1          7               27   7.5  -2.598
# 9           1          8               28   9.0   0.000
# 10          1          9               29   7.5   2.598
# 11          2          3               30   0.0   5.196
# 12          2          9               31   6.0   5.196
# 13          2         10               32   4.5   7.794
# 14          2         11               33   1.5   7.794
# 15          3          4               34  -4.5   2.598
# ...
